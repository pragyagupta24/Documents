# %%
from dputils.scrape import Scraper, Tag

# %%
query = 'phone'
page = 1
webpage = Scraper(f'https://www.amazon.in/s?k={query}&page={page}')
print(webpage.soup.title)
# Out:
# <title>Amazon.in : phone</title>

# %%
# important
target = Tag('div', cls='s-main-slot s-result-list s-search-results sg-row')
items = Tag('div', cls='s-result-item')# repeating produts
title = Tag('h2', cls='a-size-mini a-spacing-none a-color-base s-line-clamp-2')
price = Tag('span', cls='a-price-whole')
rating = Tag('i', cls='a-icon')

# %%
webpage.get_all(target, items, title=title, price=price)
# Out:
# [{'title': None, 'price': None},
#  {'title': None, 'price': None},
#  {'title': 'Nokia 105 Single SIM, Keypad Mobile Phone with Wireless FM Radio | Charcoal  ',
#   'price': '1,299'},
#  {'title': 'Nokia 110 Dual sim Keypad Phone with Wireless FM Radio, Free Earphone, Snake Game, Auto Call Recording, 1 Year Replacement Guarantee | Cyan  ',
#   'price': '1,499'},
#  {'title': 'Nokia C12 Android 12 (Go Edition) Smartphone, All-Day Battery, 4GB RAM (2GB RAM + 2GB Virtual RAM) + 64GB Capacity | Light Mint  ',
#   'price': '6,599'},
#  {'title': 'Samsung Galaxy S20 FE 5G (Cloud Mint, 8GB RAM, 128GB Storage)  ',
#   'price': '34,999'},
#  {'title': None, 'price': None},
#  {'title': 'OPPO A74 5G (Fantastic Purple,6GB RAM,128GB Storage) with No Cost EMI/Additional Exchange Offers  ',
#   'price': '15,990'},
#  {'title': 'realme narzo 50i Prime (Mint Green 3GB RAM+32GB Storage) Octa-core Processor | 5000 mAh Battery  ',
#   'price': '7,499'},
#  {'title': 'Oppo A78 5G (Glowing Black, 8GB RAM, 128 Storage) | 5000 mAh Battery with 33W SUPERVOOC Charger| 50MP AI Camera | 90Hz Refresh Rate | with No Cost EMI/Additional Exchange Offers  ',
#   'price': '18,999'},
#  {'title': 'Redmi A1 (Light Green, 2GB RAM 32GB ROM) | Segment Best AI Dual Cam | 5000mAh Battery | Leather Texture Design | Android 12  ',
#   'price': '6,499'},
#  {'title': 'Redmi A1 (Black, 2GB RAM, 32GB Storage) | Segment Best AI Dual Cam | 5000mAh Battery | Leather Texture Design | Android 12  ',
#   'price': '6,499'},
#  {'title': 'Redmi 11 Prime 5G (Chrome Silver, 4GB RAM 64GB ROM) | Prime Design | MTK Dimensity 700 | 50 MP Dual Cam | 5000mAh | 7 Band 5G  ',
#   'price': '13,999'},
#  {'title': 'Samsung Galaxy M04 Dark Blue, 4GB RAM, 64GB Storage | Upto 8GB RAM with RAM Plus | MediaTek Helio P35 | 5000 mAh Battery  ',
#   'price': '9,249'},
#  {'title': None, 'price': None},
#  {'title': 'Nokia 2660 Flip 4G Volte keypad Phone with Dual SIM, Dual Screen, inbuilt MP3 Player & Wireless FM Radio | Black  ',
#   'price': None},
#  {'title': 'Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery  ',
#   'price': '6,499'},
#  {'title': 'Redmi 10A (Charcoal Black, 4GB RAM, 64GB Storage) | 2 Ghz Octa Core Helio G25 | 5000 mAh Battery | Finger Print Sensor | Upto 5GB RAM with RAM Booster  ',
#   'price': '8,999'},
#  {'title': 'Nokia 2660 Flip 4G Volte keypad Phone with Dual SIM, Dual Screen, inbuilt MP3 Player & Wireless FM Radio | Blue  ',
#   'price': '4,499'},
#  {'title': 'OPPO A15s (Fancy White, 4GB, 128GB Storage) AI Triple Camera | 6.52" HD+ Screen | 2.3GHz Mediatek Helio P35 Octa Core Processor  ',
#   'price': '11,490'},
#  {'title': 'Samsung Galaxy M04 Light Green, 4GB RAM, 128GB Storage | Upto 8GB RAM with RAM Plus | MediaTek Helio P35 | 5000 mAh Battery  ',
#   'price': '10,249'},
#  {'title': 'Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Storage) | Octa-core Helio G35 | 5000 mAh Battery  ',
#   'price': '547.'},
#  {'title': 'Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Storage) | Octa-core Helio G35 | 5000 mAh Battery  ',
#   'price': None},
#  {'title': 'IPHONE UNLOCKED  ', 'price': '547.'},
#  {'title': 'Nillkin Galaxy S23 Ultra Case with Camera Cover, CamShield Pro for Samsung S23 Ultra Case, Slim Fit Thin Shockproof Cover for Samsung Galaxy S23 Ultra 5G 2023 (Deep Blue)  ',
#   'price': '1,270'},
#  {'title': "Nillkin A53 5G Case, for Samsung Galaxy A53 5G Case, CamShield Pro Case with Slide Camera Cover, for Samsung a53 5g A Series Smartphone case 6.46'' -2022 (Black)  ",
#   'price': '1,075'},
#  {'title': 'Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) | Segment Best AI Dual Cam | 5000mAh Battery | Leather Texture Design | Android 12  ',
#   'price': '6,499'},
#  {'title': 'Redmi 10A (Slate Grey, 4GB RAM, 64GB Storage) | 2 Ghz Octa Core Helio G25 | 5000 mAh Battery | Finger Print Sensor | Upto 5GB RAM with RAM Booster  ',
#   'price': '8,999'},
#  {'title': 'Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery  ',
#   'price': '6,499'},
#  {'title': 'Apple iPhone 13 (128GB) - Midnight  ', 'price': '61,999'},
#  {'title': None, 'price': None},
#  {'title': None, 'price': None},
#  {'title': None, 'price': None}]

# %%
def scrape_product(query, page=1):
    webpage = Scraper(f'https://www.amazon.in/s?k={query}&page={page}')
    print(webpage.soup.title)
    # important
    target = Tag('div', cls='s-main-slot s-result-list s-search-results sg-row')
    items = Tag('div', cls='s-result-item') # repeating products
    title = Tag('h2')
    price = Tag('span', cls='a-price-whole')
    rating = Tag('i', cls='a-icon a-icon-star-small a-star-small-4-5 aok-align-bottom')
    return webpage.get_all(target, items, title=title, price=price, rating=rating)

# %%
all_data = []
query='laptops'
for i in range(1, 15):
    all_data.extend(scrape_product(query, i))
    print(f'Page {i} done')
# Out:
# <title>Amazon.in : laptops</title>
# Page 1 done
# Error: 503
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 4
#       2 query='laptops'
#       3 for i in range(1, 15):
# ----> 4     all_data.extend(scrape_product(query, i))
#       5     print(f'Page {i} done')
#
# Cell In[10], line 3, in scrape_product(query, page)
#       1 def scrape_product(query, page=1):
#       2     webpage = Scraper(f'https://www.amazon.in/s?k={query}&page={page}')
# ----> 3     print(webpage.soup.title)
#       4     # important
#       5     target = Tag('div', cls='s-main-slot s-result-list s-search-results sg-row')
#
# AttributeError: 'NoneType' object has no attribute 'title'

# %%
import pandas as pd
df = pd.DataFrame(all_data).dropna(how='all')
df.to_csv('laptops.csv', index=False)

# %%
df
# Out:
#                                                 title     price  \
# 2   Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...    44,490
# 3   HP 255 G8 Laptop with AMD Athlon Silver 3050U ...    26,999
# 4   Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...    33,639
# 5   Lenovo Ideapad 3 AMD Ryzen 5 5500U 15.6" (39.6...    43,917
# 6   Crucial RAM 8GB DDR4 3200MHz CL22 (or 2933MHz ...     1,625
# 7   Crucial RAM 8GB DDR4 3200MHz CL22 (or 2933MHz ...     1,625
# 8   Crucial RAM 8GB DDR4 2666 MHz CL19 Laptop Memo...     1,799
# 9   Hynix Sk 8gb 2rx8 Pc3l-12800s 1600mhz Laptop R...       999
# 10  Samsung original 8GB 1 x 8GB 204-pin SODIMM DD...     1,800
# 11  Bennett Nylon Drax Laptops, Tablets Laptop Bag...       464
# 12  Bennett Nylon Drax Laptop Bag Sleeve Case Cove...       299
# 13  AmazonBasics Laptop Sleeve Case Cover Pouch fo...       409
# 14  HP 14s, 11th Gen Intel Core i3-1115G4, 8GB RAM...    37,490
# 16  (Renewed) Dell Latitude E5470 Intel Core i5 6t...    17,920
# 17  HP 15s, 11th Gen Intel Core i3 8GB RAM/1TB HDD...    37,490
# 18  HP 15s,11th Gen Intel Core i3-1115G4 8GB RAM/5...    40,490
# 19  Lenovo V15 AMD Ryzen 5 5500U 15.6" (39.62cm) F...    37,999
# 20  HP Pavilion 14 12th Gen Intel Core i5 16GB RAM...    66,990
# 21  Dell Inspiron 3511 Laptop, Intel i3-1115G4, 8G...    38,990
# 22  Acer Extensa 15 Lightweight Laptop Intel Core ...    42,990
# 23  Lenovo IdeaPad D330 Intel Celeron N4020 10.1" ...    20,990
# 24  HP 245 G8 3S7L2PA Notebook Business Laptop 14 ...    24,990
# 25  Lenovo V15 Intel Celeron N4020 15.6" (39.62 cm...    22,980
# 26  Lenovo V15 AMD Ryzen5 5500U 15.6" (39.62 cm) F...    35,990
# 27  HP 14s, Intel Celeron N4500, 8GB RAM/256GB SSD...    25,990
# 28  Apple 2020 MacBook Air Laptop M1 chip, 13.3-in...    84,990
# 35  (Renewed) DELL LATITUDE E7280 Lightweight (Cor...      None
# 36  Samsung Galaxy Book2 (NP750) Intel 12th Gen co...    76,990
# 37  ASUS VivoBook 14, Intel Core i3-1115G4 11th Ge...    35,990
# 38  HP 15s, AMD Ryzen 3 5300U, 15.6 inch(39.6cm) F...    39,990
# 39  HP 15s, AMD Ryzen 3 5300U, 15.6 inch(39.6cm) F...    39,990
# 40  Lenovo IdeaPad Slim 5 Intel Core i5 11th Gen 1...    57,990
# 41  Lenovo IdeaPad 3 11th Gen Intel Core i3 15.6" ...    36,158
# 42  Lenovo IdeaPad Gaming 3 Intel Core i5 11th Gen...    55,109
# 43  Lenovo IdeaPad Slim 3 Intel Core i3 12th Gen 1...    43,990
# 45  Lenovo IdeaPad Slim 3 Intel Celeron N4020 4th ...    25,685
# 46  Acer Extensa 15 Lightweight Laptop 11th Gen In...    32,489
# 47  HP 15s- Ryzen 5-5500U 8GB RAM/512GB SSD 15.6 i...    45,490
# 48  HP 15s AMD Ryzen 3-5300U 15.6inch(39.6cm) FHD ...    37,990
# 49  Apple 2020 MacBook Air Laptop M1 chip, 13.3-in...    84,990
# 50  Lenovo IdeaPad Slim 3 Chromebook Intel Celeron...    15,990
# 51  Honor MagicBook X14, 11th Gen Intel Core i5-11...    46,990
# 52  Lenovo E41-55 AMD 14-inch (35.56cm) HD Thin an...    20,999
# 53  ASUS VivoBook 15, Intel Core i3-1115G4 11th Ge...    37,990
# 54  HP 15s, Intel Core i3-1115G4, 15.6 inch(39.6cm...    39,990
# 55  Lenovo V15 AMD Ryzen 3 5300U 15.6" (39.62cm) F...    33,999
# 56  Lenovo IdeaPad Slim 3 Intel Celeron N4020 4th ...    25,480
# 57  Dell XPS 9720 Laptop, Intel i9-12900HK, 32GB D...  3,85,578
#
#                 rating
# 2   4.4 out of 5 stars
# 3                 None
# 4                 None
# 5                 None
# 6   4.5 out of 5 stars
# 7   4.5 out of 5 stars
# 8   4.5 out of 5 stars
# 9   4.3 out of 5 stars
# 10  4.3 out of 5 stars
# 11                None
# 12                None
# 13  4.3 out of 5 stars
# 14                None
# 16                None
# 17                None
# 18                None
# 19                None
# 20                None
# 21                None
# 22                None
# 23                None
# 24                None
# 25                None
# 26                None
# 27                None
# 28  4.7 out of 5 stars
# 35                None
# 36                None
# 37                None
# 38                None
# 39                None
# 40                None
# 41                None
# 42                None
# 43                None
# 45                None
# 46                None
# 47                None
# 48                None
# 49  4.7 out of 5 stars
# 50                None
# 51                None
# 52                None
# 53                None
# 54  4.4 out of 5 stars
# 55                None
# 56                None
# 57                None
