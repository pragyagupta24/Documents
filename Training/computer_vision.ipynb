# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
a = cv2.imread(r"C:\Users\hp\Downloads\kingfisher.jpg")
print(a.shape)
# Out:
# (340, 510, 3)

# %%
plt.imshow(a)

# %%
b = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
plt.imshow(b, cmap='gray')

# %%
c = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
plt.imshow(c)

# %%
d = cv2.imread(r"C:\Users\hp\Downloads\kingfisher.jpg")
plt.imshow(d)

# %%
# resize by resolution
print(a.shape)
cr = cv2.resize(c, (1600, 1500))
plt.imshow(cr)
# Out:
# (340, 510, 3)

# %%
# resize by scale
cscaled = cv2.resize(c, None, fx=0.5, fy=0.5) # image reduced by 50%
plt.imshow(cscaled)

# %%
cblur = cv2.GaussianBlur(c, (11, 11), 0)
plt.imshow(cblur)
# save this image
cblur = cv2.cvtColor(cblur, cv2.COLOR_RGB2BGR)
cv2.imwrite(r"C:\Users\hp\Downloads\kingfisher.jpg", cblur)
# Out:
# True

# %%
# apply edge detection
cgray = cv2.cvtColor(c, cv2.COLOR_RGB2GRAY)
cgray = cv2.GaussianBlur(cgray, (5, 5), 0)
cgray = cv2.Canny(cgray, 10, 150)
plt.imshow(cgray, cmap='gray')

# %%
cinvert = cv2.bitwise_not(cgray)
plt.imshow(cinvert)
